# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd 'drive/MyDrive/PDIOT-C4/'

# %%
import tensorflow as tf
tf.__version__

# %%
# !python dataset.py

# %%
# !python train.py
# Out:
# 2023-01-17 16:51:10.859583: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Epoch 1/20
# 607/607 [==============================] - 24s 20ms/step - loss: 0.9147 - accuracy: 0.6552 - val_loss: 0.6174 - val_accuracy: 0.6145 - lr: 1.0000e-04
# Epoch 2/20
# 607/607 [==============================] - 11s 19ms/step - loss: 0.2877 - accuracy: 0.8743 - val_loss: 0.0365 - val_accuracy: 0.9966 - lr: 2.0000e-04
# Epoch 3/20
# 607/607 [==============================] - 11s 19ms/step - loss: 0.0256 - accuracy: 0.9952 - val_loss: 0.0079 - val_accuracy: 0.9986 - lr: 3.0000e-04
# Epoch 4/20
# 607/607 [==============================] - 12s 20ms/step - loss: 0.0133 - accuracy: 0.9967 - val_loss: 0.0058 - val_accuracy: 0.9986 - lr: 4.0000e-04
# Epoch 5/20
# ...

# %%
# !python evaluate_models_c4.py --model_path='./model/model_trans_c4.tflite' \
                           --respeck_data_path='./Data/valid/Respeck_recordings_unseen_2022.csv' \
                           --thingy_data_path='./Data/valid/Thingy_recordings_unseen_2022.csv'
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# ********************************************************************************
# Classification report
# ********************************************************************************
#                   precision    recall  f1-score   support
#
# Sitting/Standing       1.00      0.90      0.94       738
#       Lying down       0.89      1.00      0.94       595
#          Walking       1.00      1.00      1.00       447
#          Running       1.00      1.00      1.00       145
#
#         accuracy                           0.96      1925
#        macro avg       0.97      0.97      0.97      1925
#     weighted avg       0.96      0.96      0.96      1925
